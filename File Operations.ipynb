# %%
import pandas as pd

# %%
# Importing csv files
MyPath = "C:/Users/AKSHIT/7SEM/Internship_TakenMind/RESOURCES/File Operations/demo.csv"
df = pd.read_csv(MyPath, header = None)

# Alternatively, using a custom separator
# df = pd.read_table(MyPath, sep = ",", header = None)

# %%
df
# Out:
#       0    1     2
# 0  Uber  100  1000
# 1  Grab   10   200
# 2  Lyft   30   500
# 3   Ola   90   900

# %%
# Partial importing records
df = pd.read_csv(MyPath, nrows = 2, header = None)

# %%
df
# Out:
#       0    1     2
# 0  Uber  100  1000
# 1  Grab   10   200

# %%
# Exporting to csv
df.to_csv("Dump.csv", sep = ",", columns = [0,1], header = None, index = None)

# %%
# Importing xlsx file file
MyPath = "C:/Users/AKSHIT/7SEM/Internship_TakenMind/RESOURCES/File Operations/demo2.xlsx"
excel = pd.ExcelFile(MyPath) # Read excel file
df = excel.parse("demo2") # Read sheet in file

# %%
df
# Out:
#     Cab  Revenue  Losses
# 0  Uber      100    1000
# 1  Grab       10     200
# 2  Lyft       30     500
# 3   Ola       90     900

# %%
from pandas import read_html
from bs4 import BeautifulSoup
import html5lib

# %%
# Web scraping 
url = "https://www.countrycode.org"
df_list = pd.io.html.read_html(url)
df = df_list[0]

# %%
df
# Out:
#                COUNTRY COUNTRY CODE ISO CODES  POPULATION  AREA KM2  \
# 0          Afghanistan           93  AF / AFG    29121286    647500
# 1              Albania          355  AL / ALB     2986952     28748
# 2              Algeria          213  DZ / DZA    34586184   2381740
# 3       American Samoa        1-684  AS / ASM       57881       199
# 4              Andorra          376  AD / AND       84000       468
# ..                 ...          ...       ...         ...       ...
# 235  Wallis and Futuna          681  WF / WLF       16025       274
# 236     Western Sahara          212  EH / ESH      273008    266000
# 237              Yemen          967  YE / YEM    23495361    527970
# 238             Zambia          260  ZM / ZMB    13460305    752614
# 239           Zimbabwe          263  ZW / ZWE    11651858    390580
#
#           GDP $USD
# 0    20.65 Billion
# 1     12.8 Billion
# 2    215.7 Billion
# 3    462.2 Million
# 4      4.8 Billion
# ..             ...
# ...

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)"
df_list = pd.io.html.read_html(url)
df = df_list[1]

# %%
df
# Out:
#     Rank   Country or area UN continentalregion[4] UN statisticalregion[4]  \
# 0      —             World                       —                       —
# 1      1          China[a]                    Asia            Eastern Asia
# 2      2             India                    Asia           Southern Asia
# 3      3     United States                Americas        Northern America
# 4      4         Indonesia                    Asia      South-eastern Asia
# ..   ...               ...                     ...                     ...
# 229  229        Montserrat                Americas               Caribbean
# 230  230  Falkland Islands                Americas           South America
# 231  231              Niue                 Oceania               Polynesia
# 232  232           Tokelau                 Oceania               Polynesia
# 233  233   Vatican City[t]                  Europe         Southern Europe
#
#      Population(1 July 2018)[5]  Population(1 July 2019)[5] Change
# ...
